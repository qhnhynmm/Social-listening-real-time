# %%
import pandas as pd

# Đọc dữ liệu từ file CSV (giả sử file có tên 'data.csv')
file_path = 'D:/github/Social-listening-real-time/data_producer/Dataset/all_comments.csv'
df = pd.read_csv(file_path)

# Kiểm tra và chỉ giữ lại các ngày có đủ 4 giá trị unique của cột Entity
required_entities_count = 4
filtered_df = df.groupby('Date').filter(lambda x: x['Entity'].nunique() == required_entities_count)

# Lưu kết quả vào file mới
filtered_df.to_csv('D:/github/Social-listening-real-time/data_producer/Dataset/all_comments.csv', index=False)

# %%
# Out:
#         Unnamed: 0                              ID  \
# 116756       27001  207571100452_10167581644140453
# 116757       27002  207571100452_10167581644140453
# 116758       27050  207571100452_10167581644140453
# 116759       27045  207571100452_10167581644140453
# 116760       27043  207571100452_10167581644140453
#
#                                 ID_Comment          ID_User        Entity  \
# 116756  10167581644140453_3468505316718144       1463168987  DominosPizza
# 116757   10167581644140453_765724078553232       1142902175  DominosPizza
# 116758  10167581644140453_2354706358037326  100001889760380  DominosPizza
# 116759  10167581644140453_1266042244286326  100001889760380  DominosPizza
# 116760   10167581644140453_188008227473227        551656401  DominosPizza
#
#                  Content  Comment_Like        Date
# 116756      Damon Batten             0  2023-05-04
# 116757                 🙄             0  2023-05-04
# 116758  Calvin Hampshire             0  2023-05-04
# ...
